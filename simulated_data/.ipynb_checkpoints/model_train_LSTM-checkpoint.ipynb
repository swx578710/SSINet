# %%
import tensorflow as tf
from tensorflow.keras.layers import Dense, TimeDistributed, Bidirectional, LSTM, multiply, Input, Dropout, Conv1D, Flatten
from tensorflow.keras.layers import LayerNormalization, MultiHeadAttention, Add
from tensorflow.keras.regularizers import l2
from tensorflow.keras.layers import Dense, TimeDistributed, Bidirectional, LSTM, multiply, Input, Dropout
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.layers import Dense, TimeDistributed, Bidirectional, GRU, multiply, Input, Dropout
from esinet import util
from tensorflow.keras.layers import LSTM
from esinet import Simulation, Net
from esinet.forward import create_forward_model, get_info
import numpy as np
from tensorflow.keras.layers import Dense, TimeDistributed, Bidirectional, LSTM, Input, Dropout, concatenate
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.layers import Dense, TimeDistributed, Bidirectional, LSTM, multiply, Input, Dropout
from tensorflow.keras.callbacks import EarlyStopping, LearningRateScheduler
import copy

# %%
def transformer_encoder(inputs, head_size, num_heads, ff_dim, dropout=0):
    # Normalization and Attention
    x = LayerNormalization(epsilon=1e-6)(inputs)
    x = MultiHeadAttention(key_dim=head_size, num_heads=num_heads, dropout=dropout)(x, x)
    x = Add()([x, inputs])

    # Feed Forward Part
    ff = LayerNormalization(epsilon=1e-6)(x)
    ff = TimeDistributed(Dense(ff_dim, activation="relu"))(ff)
    ff = Dropout(dropout)(ff)
    ff = TimeDistributed(Dense(inputs.shape[-1]))(ff)
    ff = Add()([ff, x])

    return ff

# %%
# 定义损失函数
def myself_loss(y_true, y_pred):
	losses = y_true - y_pred
	return losses

# %%
# 对输入eeg进行归一化
def custom_prep_data(data):

    data = np.swapaxes(data, 1,2)

    # 获取数据维度
    num_samples, num_timepoints, num_channels = data.shape
    
    # 将数据类型转换为 np.float32
    data = data.astype(np.float32)
    
    # 对每个样本（脑电信号的一个时间点）进行处理
    for i in range(num_samples):
        for j in range(num_timepoints):
            # 获取当前样本的数据
            sample_data = data[i, j, :]
            
            # 假设你想要进行去除平均值和标准化的预处理
            # 去除平均值
            sample_data_mean = np.mean(sample_data)
            sample_data_std = np.std(sample_data)
            sample_data -= sample_data_mean
            
            # 标准化
            if sample_data_std != 0:
                sample_data /= sample_data_std
        
            # 更新数据
            data[i, j, :] = sample_data
    print("The shape of EEG is", data.shape)
    
    return data

# 对源信号进行归一化
def custom_prep_source(data):
    
    # 将数据类型转换为 np.float32
    data = data.astype(np.float32)
    
    for i, y_sample in enumerate(data):
        data[i] /= np.max(abs(data[i]))

    data = np.swapaxes(data, 1,2)
    print("The shape of source is", data.shape)
    
    return data

# %%
# 定义学习率调度函数
def lr_schedule(epoch):
    # 根据训练周期(epoch)来动态调整学习率
    if epoch < 50:
        return 0.001
    elif epoch < 100:
        return 0.005
    else:
        return 0.0005

# %%
# 构建LSTM神经网络,损失函数有余弦相似度 CosineSimilarity, Huber
lr_scheduler = LearningRateScheduler(lr_schedule)
# 超参数定义
n_channels = 60
n_dipoles = 844 
n_dense_units = 200  # 减少单元数
n_lstm_units = 32    # 减少单元数
dropout_rate = 0.2
batch_size = 256
epochs = 200

# 输入层
inputs = tf.keras.Input(shape=(None, n_channels), name='Input')
## 全连接路径
fc1 = TimeDistributed(Dense(n_dense_units, 
            activation="tanh"), 
            name='FC1')(inputs)
fc1 = Dropout(dropout_rate)(fc1)
direct_out = TimeDistributed(Dense(n_dipoles, 
    activation="linear"),
    name='FC2')(fc1)
# LSTM路径,Mask层的作用是生成一个与输入序列形状相同的掩码，用于动态地控制对输出序列的处理，以处理变长时间序列
# 在源定位中，不同信号的长度可能不同，但我们通常希望在模型中对它们进行统一处理。这就需要通过掩码来标记填充的部分，并在计算损失时忽略这些填充的部分。
lstm1 = Bidirectional(GRU(n_lstm_units, return_sequences=True, 
    input_shape=(None, n_dense_units), dropout=dropout_rate), 
    name='LSTM1')(fc1)
mask = TimeDistributed(Dense(n_dipoles, 
            activation="sigmoid"), 
            name='Mask')(lstm1)

# Combination
multi = multiply([direct_out, mask], name="multiply")
model = tf.keras.Model(inputs=inputs, outputs=multi, name='Contextualizer')
model.compile(loss=tf.keras.losses.CosineSimilarity(), optimizer=tf.keras.optimizers.Adam(learning_rate=0.001))

# 打印模型概要
model.summary()
# Out:
# Model: "Contextualizer"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  Input (InputLayer)             [(None, None, 60)]   0           []
#
#  FC1 (TimeDistributed)          (None, None, 200)    12200       ['Input[0][0]']
#
#  dropout_3 (Dropout)            (None, None, 200)    0           ['FC1[0][0]']
#
#  LSTM1 (Bidirectional)          (None, None, 64)     44928       ['dropout_3[0][0]']
#
#  FC2 (TimeDistributed)          (None, None, 1284)   258084      ['dropout_3[0][0]']
#
#  Mask (TimeDistributed)         (None, None, 1284)   83460       ['LSTM1[0][0]']
#
#  multiply (Multiply)            (None, None, 1284)   0           ['FC2[0][0]',
#                                                                   'Mask[0][0]']
#
# ==================================================================================================
# Total params: 398,672
# Trainable params: 398,672
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
# 加载测试数据
x= np.load('x_daodianlv.npy')
y= np.load('y_daodianlv.npy')
print(x.shape)
print(y.shape)
# Out:
# (20000, 60, 26)
# (20000, 1284, 26)

# %%
 # 对信号进行预处理
x = custom_prep_data(x)
y = custom_prep_source(y)
# Out:
# The shape of EEG is (20000, 26, 60)
# The shape of source is (20000, 26, 1284)

# %%
# 使用数据生成器进行训练
def data_generator(x, y, batch_size):
    num_samples = len(x)
    indices = np.arange(num_samples)
    
    while True:
        np.random.shuffle(indices)
        for i in range(0, num_samples, batch_size):
            batch_indices = indices[i:i + batch_size]
            yield x[batch_indices], y[batch_indices]

# %%
# Split data into training and validation sets
split_index = int(0.9 * len(x))
x_train, x_val = x[:split_index], x[split_index:]
y_train, y_val = y[:split_index], y[split_index:]

# %%
# Create data generators for training and validation
train_generator = data_generator(x_train, y_train, batch_size)
val_generator = data_generator(x_val, y_val, batch_size)
early_stopping = EarlyStopping(monitor='val_loss', mode='min', patience=30, restore_best_weights=True)

# %%
# 计算每个epoch的步骤和验证步骤
steps_per_epoch = len(x_train) // batch_size
validation_steps = len(x_val) // batch_size

# %%
# 训练模型时使用学习率调度器
history = model.fit(
    train_generator,
    epochs=epochs,
    steps_per_epoch=steps_per_epoch,
    validation_data=val_generator,
    validation_steps=validation_steps,
    callbacks=[early_stopping, lr_scheduler]  # 添加学习率调度器回调
)
# Out:
# Epoch 1/200
# 70/70 [==============================] - 8s 53ms/step - loss: -0.2102 - val_loss: -0.3026 - lr: 0.0010
# Epoch 2/200
# 70/70 [==============================] - 3s 41ms/step - loss: -0.3283 - val_loss: -0.3730 - lr: 0.0010
# Epoch 3/200
# 70/70 [==============================] - 3s 41ms/step - loss: -0.3887 - val_loss: -0.4229 - lr: 0.0010
# Epoch 4/200
# 70/70 [==============================] - 3s 41ms/step - loss: -0.4328 - val_loss: -0.4551 - lr: 0.0010
# Epoch 5/200
# 70/70 [==============================] - 3s 45ms/step - loss: -0.4595 - val_loss: -0.4733 - lr: 0.0010
# Epoch 6/200
# 70/70 [==============================] - 3s 43ms/step - loss: -0.4759 - val_loss: -0.4869 - lr: 0.0010
# Epoch 7/200
# 70/70 [==============================] - 3s 45ms/step - loss: -0.4889 - val_loss: -0.4983 - lr: 0.0010
# Epoch 8/200
# 70/70 [==============================] - 3s 44ms/step - loss: -0.4990 - val_loss: -0.5021 - lr: 0.0010
# Epoch 9/200
# 70/70 [==============================] - 3s 44ms/step - loss: -0.5082 - val_loss: -0.5098 - lr: 0.0010
# Epoch 10/200
# 70/70 [==============================] - 3s 42ms/step - loss: -0.5129 - val_loss: -0.5148 - lr: 0.0010
# Epoch 11/200
# 70/70 [==============================] - 3s 41ms/step - loss: -0.5199 - val_loss: -0.5140 - lr: 0.0010
# Epoch 12/200
# 70/70 [==============================] - 3s 42ms/step - loss: -0.5256 - val_loss: -0.5209 - lr: 0.0010
# Epoch 13/200
# 70/70 [==============================] - 3s 43ms/step - loss: -0.5279 - val_loss: -0.5252 - lr: 0.0010
# Epoch 14/200
# 70/70 [==============================] - 3s 43ms/step - loss: -0.5339 - val_loss: -0.5260 - lr: 0.0010
# Epoch 15/200
# 70/70 [==============================] - 3s 43ms/step - loss: -0.5388 - val_loss: -0.5276 - lr: 0.0010
# Epoch 16/200
# 70/70 [==============================] - 3s 42ms/step - loss: -0.5415 - val_loss: -0.5302 - lr: 0.0010
# Epoch 17/200
# 70/70 [==============================] - 3s 42ms/step - loss: -0.5454 - val_loss: -0.5304 - lr: 0.0010
# Epoch 18/200
# 70/70 [==============================] - 3s 41ms/step - loss: -0.5487 - val_loss: -0.5308 - lr: 0.0010
# Epoch 19/200
# 70/70 [==============================] - 3s 42ms/step - loss: -0.5504 - val_loss: -0.5322 - lr: 0.0010
# Epoch 20/200
# 70/70 [==============================] - 3s 44ms/step - loss: -0.5542 - val_loss: -0.5345 - lr: 0.0010
# Epoch 21/200
# 70/70 [==============================] - 3s 42ms/step - loss: -0.5552 - val_loss: -0.5353 - lr: 0.0010
# Epoch 22/200
# 70/70 [==============================] - 3s 42ms/step - loss: -0.5604 - val_loss: -0.5380 - lr: 0.0010
# Epoch 23/200
# 70/70 [==============================] - 3s 42ms/step - loss: -0.5614 - val_loss: -0.5386 - lr: 0.0010
# Epoch 24/200
# 70/70 [==============================] - 3s 41ms/step - loss: -0.5618 - val_loss: -0.5380 - lr: 0.0010
# Epoch 25/200
# 70/70 [==============================] - 3s 41ms/step - loss: -0.5667 - val_loss: -0.5353 - lr: 0.0010
# Epoch 26/200
# 70/70 [==============================] - 3s 43ms/step - loss: -0.5679 - val_loss: -0.5413 - lr: 0.0010
# Epoch 27/200
# 70/70 [==============================] - 3s 47ms/step - loss: -0.5676 - val_loss: -0.5407 - lr: 0.0010
# Epoch 28/200
# 70/70 [==============================] - 3s 43ms/step - loss: -0.5708 - val_loss: -0.5386 - lr: 0.0010
# Epoch 29/200
# 70/70 [==============================] - 3s 43ms/step - loss: -0.5737 - val_loss: -0.5438 - lr: 0.0010
# Epoch 30/200
# 70/70 [==============================] - 3s 41ms/step - loss: -0.5750 - val_loss: -0.5419 - lr: 0.0010
# Epoch 31/200
# 70/70 [==============================] - 3s 42ms/step - loss: -0.5772 - val_loss: -0.5458 - lr: 0.0010
# Epoch 32/200
# 70/70 [==============================] - 3s 43ms/step - loss: -0.5778 - val_loss: -0.5455 - lr: 0.0010
# Epoch 33/200
# 70/70 [==============================] - 3s 42ms/step - loss: -0.5793 - val_loss: -0.5448 - lr: 0.0010
# Epoch 34/200
# 70/70 [==============================] - 3s 43ms/step - loss: -0.5819 - val_loss: -0.5457 - lr: 0.0010
# Epoch 35/200
# 70/70 [==============================] - 3s 43ms/step - loss: -0.5823 - val_loss: -0.5474 - lr: 0.0010
# Epoch 36/200
# 70/70 [==============================] - 3s 44ms/step - loss: -0.5837 - val_loss: -0.5470 - lr: 0.0010
# Epoch 37/200
# 70/70 [==============================] - 3s 43ms/step - loss: -0.5847 - val_loss: -0.5470 - lr: 0.0010
# Epoch 38/200
# 70/70 [==============================] - 3s 43ms/step - loss: -0.5864 - val_loss: -0.5486 - lr: 0.0010
# Epoch 39/200
# 70/70 [==============================] - 3s 43ms/step - loss: -0.5903 - val_loss: -0.5491 - lr: 0.0010
# Epoch 40/200
# 70/70 [==============================] - 3s 43ms/step - loss: -0.5874 - val_loss: -0.5486 - lr: 0.0010
# Epoch 41/200
# 70/70 [==============================] - 3s 43ms/step - loss: -0.5899 - val_loss: -0.5485 - lr: 0.0010
# Epoch 42/200
# 70/70 [==============================] - 3s 43ms/step - loss: -0.5913 - val_loss: -0.5497 - lr: 0.0010
# Epoch 43/200
# 70/70 [==============================] - 3s 43ms/step - loss: -0.5921 - val_loss: -0.5533 - lr: 0.0010
# Epoch 44/200
# 70/70 [==============================] - 3s 43ms/step - loss: -0.5934 - val_loss: -0.5542 - lr: 0.0010
# Epoch 45/200
# 70/70 [==============================] - 3s 43ms/step - loss: -0.5936 - val_loss: -0.5523 - lr: 0.0010
# Epoch 46/200
# 70/70 [==============================] - 3s 42ms/step - loss: -0.5964 - val_loss: -0.5493 - lr: 0.0010
# Epoch 47/200
# 70/70 [==============================] - 3s 43ms/step - loss: -0.5962 - val_loss: -0.5522 - lr: 0.0010
# Epoch 48/200
# 70/70 [==============================] - 3s 43ms/step - loss: -0.5965 - val_loss: -0.5518 - lr: 0.0010
# Epoch 49/200
# 70/70 [==============================] - 3s 43ms/step - loss: -0.5981 - val_loss: -0.5561 - lr: 0.0010
# Epoch 50/200
# 70/70 [==============================] - 3s 43ms/step - loss: -0.6007 - val_loss: -0.5544 - lr: 0.0010
# Epoch 51/200
# 70/70 [==============================] - 3s 44ms/step - loss: -0.5701 - val_loss: -0.5370 - lr: 0.0050
# Epoch 52/200
# 70/70 [==============================] - 3s 42ms/step - loss: -0.5710 - val_loss: -0.5396 - lr: 0.0050
# Epoch 53/200
# 70/70 [==============================] - 3s 41ms/step - loss: -0.5760 - val_loss: -0.5416 - lr: 0.0050
# Epoch 54/200
# 70/70 [==============================] - 3s 42ms/step - loss: -0.5788 - val_loss: -0.5431 - lr: 0.0050
# Epoch 55/200
# 70/70 [==============================] - 3s 43ms/step - loss: -0.5808 - val_loss: -0.5445 - lr: 0.0050
# Epoch 56/200
# 70/70 [==============================] - 3s 42ms/step - loss: -0.5849 - val_loss: -0.5497 - lr: 0.0050
# Epoch 57/200
# 70/70 [==============================] - 3s 43ms/step - loss: -0.5878 - val_loss: -0.5497 - lr: 0.0050
# Epoch 58/200
# 70/70 [==============================] - 3s 43ms/step - loss: -0.5894 - val_loss: -0.5504 - lr: 0.0050
# Epoch 59/200
# 70/70 [==============================] - 3s 43ms/step - loss: -0.5898 - val_loss: -0.5498 - lr: 0.0050
# Epoch 60/200
# 70/70 [==============================] - 3s 41ms/step - loss: -0.5946 - val_loss: -0.5460 - lr: 0.0050
# Epoch 61/200
# 70/70 [==============================] - 3s 41ms/step - loss: -0.5958 - val_loss: -0.5490 - lr: 0.0050
# Epoch 62/200
# 70/70 [==============================] - 3s 41ms/step - loss: -0.5969 - val_loss: -0.5507 - lr: 0.0050
# Epoch 63/200
# 70/70 [==============================] - 3s 41ms/step - loss: -0.5985 - val_loss: -0.5520 - lr: 0.0050
# Epoch 64/200
# 70/70 [==============================] - 3s 40ms/step - loss: -0.6001 - val_loss: -0.5542 - lr: 0.0050
# Epoch 65/200
# 70/70 [==============================] - 3s 41ms/step - loss: -0.6026 - val_loss: -0.5523 - lr: 0.0050
# Epoch 66/200
# 70/70 [==============================] - 3s 41ms/step - loss: -0.6035 - val_loss: -0.5536 - lr: 0.0050
# Epoch 67/200
# 70/70 [==============================] - 3s 42ms/step - loss: -0.6061 - val_loss: -0.5551 - lr: 0.0050
# Epoch 68/200
# 70/70 [==============================] - 3s 43ms/step - loss: -0.6077 - val_loss: -0.5522 - lr: 0.0050
# Epoch 69/200
# 70/70 [==============================] - 3s 41ms/step - loss: -0.6074 - val_loss: -0.5508 - lr: 0.0050
# Epoch 70/200
# 70/70 [==============================] - 3s 41ms/step - loss: -0.6099 - val_loss: -0.5592 - lr: 0.0050
# Epoch 71/200
# 70/70 [==============================] - 3s 40ms/step - loss: -0.6113 - val_loss: -0.5561 - lr: 0.0050
# Epoch 72/200
# 70/70 [==============================] - 3s 41ms/step - loss: -0.6123 - val_loss: -0.5621 - lr: 0.0050
# Epoch 73/200
# 70/70 [==============================] - 3s 41ms/step - loss: -0.6143 - val_loss: -0.5605 - lr: 0.0050
# Epoch 74/200
# 70/70 [==============================] - 3s 41ms/step - loss: -0.6141 - val_loss: -0.5619 - lr: 0.0050
# Epoch 75/200
# 70/70 [==============================] - 3s 41ms/step - loss: -0.6153 - val_loss: -0.5635 - lr: 0.0050
# Epoch 76/200
# 70/70 [==============================] - 3s 41ms/step - loss: -0.6164 - val_loss: -0.5612 - lr: 0.0050
# Epoch 77/200
# 70/70 [==============================] - 3s 40ms/step - loss: -0.6176 - val_loss: -0.5626 - lr: 0.0050
# Epoch 78/200
# 70/70 [==============================] - 3s 41ms/step - loss: -0.6199 - val_loss: -0.5647 - lr: 0.0050
# Epoch 79/200
# 70/70 [==============================] - 3s 41ms/step - loss: -0.6202 - val_loss: -0.5625 - lr: 0.0050
# Epoch 80/200
# 70/70 [==============================] - 3s 41ms/step - loss: -0.6208 - val_loss: -0.5654 - lr: 0.0050
# Epoch 81/200
# 70/70 [==============================] - 3s 42ms/step - loss: -0.6208 - val_loss: -0.5657 - lr: 0.0050
# Epoch 82/200
# 70/70 [==============================] - 3s 41ms/step - loss: -0.6221 - val_loss: -0.5639 - lr: 0.0050
# Epoch 83/200
# 70/70 [==============================] - 3s 41ms/step - loss: -0.6238 - val_loss: -0.5693 - lr: 0.0050
# Epoch 84/200
# 70/70 [==============================] - 3s 41ms/step - loss: -0.6252 - val_loss: -0.5682 - lr: 0.0050
# Epoch 85/200
# 70/70 [==============================] - 3s 41ms/step - loss: -0.6241 - val_loss: -0.5683 - lr: 0.0050
# Epoch 86/200
# 70/70 [==============================] - 3s 41ms/step - loss: -0.6252 - val_loss: -0.5683 - lr: 0.0050
# Epoch 87/200
# 70/70 [==============================] - 3s 41ms/step - loss: -0.6267 - val_loss: -0.5662 - lr: 0.0050
# Epoch 88/200
# 70/70 [==============================] - 3s 41ms/step - loss: -0.6269 - val_loss: -0.5683 - lr: 0.0050
# Epoch 89/200
# 70/70 [==============================] - 3s 41ms/step - loss: -0.6251 - val_loss: -0.5669 - lr: 0.0050
# Epoch 90/200
# 70/70 [==============================] - 3s 41ms/step - loss: -0.6295 - val_loss: -0.5665 - lr: 0.0050
# Epoch 91/200
# 70/70 [==============================] - 3s 40ms/step - loss: -0.6287 - val_loss: -0.5682 - lr: 0.0050
# Epoch 92/200
# 70/70 [==============================] - 3s 41ms/step - loss: -0.6310 - val_loss: -0.5731 - lr: 0.0050
# Epoch 93/200
# 70/70 [==============================] - 3s 42ms/step - loss: -0.6316 - val_loss: -0.5719 - lr: 0.0050
# Epoch 94/200
# 70/70 [==============================] - 3s 43ms/step - loss: -0.6303 - val_loss: -0.5720 - lr: 0.0050
# Epoch 95/200
# 70/70 [==============================] - 3s 43ms/step - loss: -0.6305 - val_loss: -0.5703 - lr: 0.0050
# Epoch 96/200
# 70/70 [==============================] - 3s 43ms/step - loss: -0.6323 - val_loss: -0.5688 - lr: 0.0050
# Epoch 97/200
# 70/70 [==============================] - 3s 43ms/step - loss: -0.6309 - val_loss: -0.5736 - lr: 0.0050
# Epoch 98/200
# 70/70 [==============================] - 3s 42ms/step - loss: -0.6356 - val_loss: -0.5729 - lr: 0.0050
# Epoch 99/200
# 70/70 [==============================] - 3s 41ms/step - loss: -0.6338 - val_loss: -0.5716 - lr: 0.0050
# Epoch 100/200
# 70/70 [==============================] - 3s 41ms/step - loss: -0.6340 - val_loss: -0.5716 - lr: 0.0050
# Epoch 101/200
# 70/70 [==============================] - 3s 41ms/step - loss: -0.6476 - val_loss: -0.5792 - lr: 5.0000e-04
# Epoch 102/200
# 70/70 [==============================] - 3s 42ms/step - loss: -0.6550 - val_loss: -0.5851 - lr: 5.0000e-04
# Epoch 103/200
# 70/70 [==============================] - 3s 43ms/step - loss: -0.6581 - val_loss: -0.5829 - lr: 5.0000e-04
# Epoch 104/200
# 70/70 [==============================] - 3s 43ms/step - loss: -0.6577 - val_loss: -0.5844 - lr: 5.0000e-04
# Epoch 105/200
# 70/70 [==============================] - 3s 42ms/step - loss: -0.6579 - val_loss: -0.5836 - lr: 5.0000e-04
# Epoch 106/200
# 70/70 [==============================] - 3s 41ms/step - loss: -0.6589 - val_loss: -0.5859 - lr: 5.0000e-04
# Epoch 107/200
# 70/70 [==============================] - 3s 41ms/step - loss: -0.6595 - val_loss: -0.5857 - lr: 5.0000e-04
# Epoch 108/200
# 70/70 [==============================] - 3s 43ms/step - loss: -0.6608 - val_loss: -0.5872 - lr: 5.0000e-04
# Epoch 109/200
# 70/70 [==============================] - 3s 46ms/step - loss: -0.6595 - val_loss: -0.5845 - lr: 5.0000e-04
# Epoch 110/200
# 70/70 [==============================] - 3s 41ms/step - loss: -0.6608 - val_loss: -0.5864 - lr: 5.0000e-04
# Epoch 111/200
# 70/70 [==============================] - 3s 42ms/step - loss: -0.6605 - val_loss: -0.5861 - lr: 5.0000e-04
# Epoch 112/200
# 70/70 [==============================] - 3s 41ms/step - loss: -0.6620 - val_loss: -0.5855 - lr: 5.0000e-04
# Epoch 113/200
# 70/70 [==============================] - 3s 41ms/step - loss: -0.6605 - val_loss: -0.5874 - lr: 5.0000e-04
# Epoch 114/200
# 70/70 [==============================] - 3s 41ms/step - loss: -0.6621 - val_loss: -0.5879 - lr: 5.0000e-04
# Epoch 115/200
# 70/70 [==============================] - 3s 41ms/step - loss: -0.6616 - val_loss: -0.5863 - lr: 5.0000e-04
# Epoch 116/200
# 70/70 [==============================] - 3s 42ms/step - loss: -0.6606 - val_loss: -0.5892 - lr: 5.0000e-04
# Epoch 117/200
# 70/70 [==============================] - 3s 41ms/step - loss: -0.6628 - val_loss: -0.5851 - lr: 5.0000e-04
# Epoch 118/200
# 70/70 [==============================] - 3s 41ms/step - loss: -0.6611 - val_loss: -0.5863 - lr: 5.0000e-04
# Epoch 119/200
# 70/70 [==============================] - 3s 41ms/step - loss: -0.6605 - val_loss: -0.5868 - lr: 5.0000e-04
# Epoch 120/200
# 70/70 [==============================] - 3s 41ms/step - loss: -0.6644 - val_loss: -0.5873 - lr: 5.0000e-04
# Epoch 121/200
# 70/70 [==============================] - 3s 41ms/step - loss: -0.6627 - val_loss: -0.5862 - lr: 5.0000e-04
# Epoch 122/200
# 70/70 [==============================] - 3s 41ms/step - loss: -0.6635 - val_loss: -0.5862 - lr: 5.0000e-04
# Epoch 123/200
# 70/70 [==============================] - 3s 41ms/step - loss: -0.6624 - val_loss: -0.5850 - lr: 5.0000e-04
# Epoch 124/200
# 70/70 [==============================] - 3s 41ms/step - loss: -0.6632 - val_loss: -0.5868 - lr: 5.0000e-04
# Epoch 125/200
# 70/70 [==============================] - 3s 41ms/step - loss: -0.6638 - val_loss: -0.5898 - lr: 5.0000e-04
# Epoch 126/200
# 70/70 [==============================] - 3s 41ms/step - loss: -0.6625 - val_loss: -0.5868 - lr: 5.0000e-04
# Epoch 127/200
# 70/70 [==============================] - 3s 42ms/step - loss: -0.6630 - val_loss: -0.5894 - lr: 5.0000e-04
# Epoch 128/200
# 70/70 [==============================] - 3s 41ms/step - loss: -0.6637 - val_loss: -0.5859 - lr: 5.0000e-04
# Epoch 129/200
# 70/70 [==============================] - 3s 41ms/step - loss: -0.6647 - val_loss: -0.5902 - lr: 5.0000e-04
# Epoch 130/200
# 70/70 [==============================] - 3s 41ms/step - loss: -0.6647 - val_loss: -0.5886 - lr: 5.0000e-04
# Epoch 131/200
# 70/70 [==============================] - 3s 41ms/step - loss: -0.6625 - val_loss: -0.5865 - lr: 5.0000e-04
# Epoch 132/200
# 70/70 [==============================] - 3s 41ms/step - loss: -0.6657 - val_loss: -0.5889 - lr: 5.0000e-04
# Epoch 133/200
# 70/70 [==============================] - 3s 41ms/step - loss: -0.6637 - val_loss: -0.5880 - lr: 5.0000e-04
# Epoch 134/200
# 70/70 [==============================] - 3s 40ms/step - loss: -0.6657 - val_loss: -0.5879 - lr: 5.0000e-04
# Epoch 135/200
# 70/70 [==============================] - 3s 41ms/step - loss: -0.6641 - val_loss: -0.5885 - lr: 5.0000e-04
# Epoch 136/200
# 70/70 [==============================] - 3s 41ms/step - loss: -0.6646 - val_loss: -0.5890 - lr: 5.0000e-04
# Epoch 137/200
# 70/70 [==============================] - 3s 41ms/step - loss: -0.6651 - val_loss: -0.5911 - lr: 5.0000e-04
# Epoch 138/200
# 70/70 [==============================] - 3s 41ms/step - loss: -0.6649 - val_loss: -0.5888 - lr: 5.0000e-04
# Epoch 139/200
# 70/70 [==============================] - 3s 41ms/step - loss: -0.6653 - val_loss: -0.5889 - lr: 5.0000e-04
# Epoch 140/200
# 70/70 [==============================] - 3s 41ms/step - loss: -0.6656 - val_loss: -0.5895 - lr: 5.0000e-04
# Epoch 141/200
# 70/70 [==============================] - 3s 41ms/step - loss: -0.6653 - val_loss: -0.5894 - lr: 5.0000e-04
# Epoch 142/200
# 70/70 [==============================] - 3s 41ms/step - loss: -0.6655 - val_loss: -0.5856 - lr: 5.0000e-04
# Epoch 143/200
# 70/70 [==============================] - 3s 41ms/step - loss: -0.6660 - val_loss: -0.5888 - lr: 5.0000e-04
# Epoch 144/200
# 70/70 [==============================] - 3s 41ms/step - loss: -0.6666 - val_loss: -0.5893 - lr: 5.0000e-04
# Epoch 145/200
# 70/70 [==============================] - 3s 41ms/step - loss: -0.6655 - val_loss: -0.5887 - lr: 5.0000e-04
# Epoch 146/200
# 70/70 [==============================] - 3s 41ms/step - loss: -0.6661 - val_loss: -0.5893 - lr: 5.0000e-04
# Epoch 147/200
# 70/70 [==============================] - 3s 41ms/step - loss: -0.6666 - val_loss: -0.5860 - lr: 5.0000e-04
# Epoch 148/200
# 70/70 [==============================] - 3s 41ms/step - loss: -0.6665 - val_loss: -0.5895 - lr: 5.0000e-04
# Epoch 149/200
# 70/70 [==============================] - 3s 41ms/step - loss: -0.6656 - val_loss: -0.5883 - lr: 5.0000e-04
# Epoch 150/200
# 70/70 [==============================] - 3s 41ms/step - loss: -0.6672 - val_loss: -0.5890 - lr: 5.0000e-04
# Epoch 151/200
# 70/70 [==============================] - 3s 44ms/step - loss: -0.6662 - val_loss: -0.5885 - lr: 5.0000e-04
# Epoch 152/200
# 70/70 [==============================] - 3s 41ms/step - loss: -0.6663 - val_loss: -0.5897 - lr: 5.0000e-04
# Epoch 153/200
# 70/70 [==============================] - 3s 41ms/step - loss: -0.6679 - val_loss: -0.5902 - lr: 5.0000e-04
# Epoch 154/200
# 70/70 [==============================] - 3s 41ms/step - loss: -0.6656 - val_loss: -0.5867 - lr: 5.0000e-04
# Epoch 155/200
# 70/70 [==============================] - 3s 41ms/step - loss: -0.6681 - val_loss: -0.5881 - lr: 5.0000e-04
# Epoch 156/200
# 70/70 [==============================] - 3s 41ms/step - loss: -0.6666 - val_loss: -0.5867 - lr: 5.0000e-04
# Epoch 157/200
# 70/70 [==============================] - 3s 41ms/step - loss: -0.6681 - val_loss: -0.5896 - lr: 5.0000e-04
# Epoch 158/200
# 70/70 [==============================] - 3s 41ms/step - loss: -0.6677 - val_loss: -0.5875 - lr: 5.0000e-04
# Epoch 159/200
# 70/70 [==============================] - 3s 42ms/step - loss: -0.6665 - val_loss: -0.5891 - lr: 5.0000e-04
# Epoch 160/200
# 70/70 [==============================] - 3s 41ms/step - loss: -0.6675 - val_loss: -0.5891 - lr: 5.0000e-04
# Epoch 161/200
# 70/70 [==============================] - 3s 41ms/step - loss: -0.6685 - val_loss: -0.5893 - lr: 5.0000e-04
# Epoch 162/200
# 70/70 [==============================] - 3s 41ms/step - loss: -0.6662 - val_loss: -0.5870 - lr: 5.0000e-04
# Epoch 163/200
# 70/70 [==============================] - 3s 41ms/step - loss: -0.6689 - val_loss: -0.5886 - lr: 5.0000e-04
# Epoch 164/200
# 70/70 [==============================] - 3s 42ms/step - loss: -0.6676 - val_loss: -0.5887 - lr: 5.0000e-04
# Epoch 165/200
# 70/70 [==============================] - 3s 43ms/step - loss: -0.6685 - val_loss: -0.5919 - lr: 5.0000e-04
# Epoch 166/200
# 70/70 [==============================] - 3s 42ms/step - loss: -0.6681 - val_loss: -0.5903 - lr: 5.0000e-04
# Epoch 167/200
# 70/70 [==============================] - 3s 42ms/step - loss: -0.6678 - val_loss: -0.5880 - lr: 5.0000e-04
# Epoch 168/200
# 70/70 [==============================] - 3s 42ms/step - loss: -0.6685 - val_loss: -0.5892 - lr: 5.0000e-04
# Epoch 169/200
# 70/70 [==============================] - 3s 43ms/step - loss: -0.6674 - val_loss: -0.5883 - lr: 5.0000e-04
# Epoch 170/200
# 70/70 [==============================] - 3s 43ms/step - loss: -0.6691 - val_loss: -0.5869 - lr: 5.0000e-04
# Epoch 171/200
# 70/70 [==============================] - 3s 43ms/step - loss: -0.6682 - val_loss: -0.5897 - lr: 5.0000e-04
# Epoch 172/200
# 70/70 [==============================] - 3s 44ms/step - loss: -0.6678 - val_loss: -0.5898 - lr: 5.0000e-04
# Epoch 173/200
# 70/70 [==============================] - 3s 43ms/step - loss: -0.6703 - val_loss: -0.5907 - lr: 5.0000e-04
# Epoch 174/200
# 70/70 [==============================] - 3s 43ms/step - loss: -0.6676 - val_loss: -0.5892 - lr: 5.0000e-04
# Epoch 175/200
# 70/70 [==============================] - 3s 42ms/step - loss: -0.6695 - val_loss: -0.5897 - lr: 5.0000e-04
# Epoch 176/200
# 70/70 [==============================] - 3s 42ms/step - loss: -0.6689 - val_loss: -0.5920 - lr: 5.0000e-04
# Epoch 177/200
# 70/70 [==============================] - 3s 44ms/step - loss: -0.6682 - val_loss: -0.5916 - lr: 5.0000e-04
# Epoch 178/200
# 70/70 [==============================] - 3s 43ms/step - loss: -0.6700 - val_loss: -0.5912 - lr: 5.0000e-04
# Epoch 179/200
# 70/70 [==============================] - 3s 41ms/step - loss: -0.6682 - val_loss: -0.5887 - lr: 5.0000e-04
# Epoch 180/200
# 70/70 [==============================] - 3s 41ms/step - loss: -0.6709 - val_loss: -0.5930 - lr: 5.0000e-04
# Epoch 181/200
# 70/70 [==============================] - 3s 42ms/step - loss: -0.6684 - val_loss: -0.5903 - lr: 5.0000e-04
# Epoch 182/200
# 70/70 [==============================] - 3s 42ms/step - loss: -0.6700 - val_loss: -0.5883 - lr: 5.0000e-04
# Epoch 183/200
# 70/70 [==============================] - 3s 42ms/step - loss: -0.6691 - val_loss: -0.5897 - lr: 5.0000e-04
# Epoch 184/200
# 70/70 [==============================] - 3s 46ms/step - loss: -0.6702 - val_loss: -0.5896 - lr: 5.0000e-04
# Epoch 185/200
# 70/70 [==============================] - 3s 42ms/step - loss: -0.6683 - val_loss: -0.5901 - lr: 5.0000e-04
# Epoch 186/200
# 70/70 [==============================] - 3s 42ms/step - loss: -0.6698 - val_loss: -0.5926 - lr: 5.0000e-04
# Epoch 187/200
# 70/70 [==============================] - 3s 42ms/step - loss: -0.6695 - val_loss: -0.5910 - lr: 5.0000e-04
# Epoch 188/200
# 70/70 [==============================] - 3s 44ms/step - loss: -0.6701 - val_loss: -0.5917 - lr: 5.0000e-04
# Epoch 189/200
# 70/70 [==============================] - 3s 43ms/step - loss: -0.6697 - val_loss: -0.5916 - lr: 5.0000e-04
# Epoch 190/200
# 70/70 [==============================] - 3s 43ms/step - loss: -0.6705 - val_loss: -0.5897 - lr: 5.0000e-04
# Epoch 191/200
# 70/70 [==============================] - 4s 56ms/step - loss: -0.6704 - val_loss: -0.5901 - lr: 5.0000e-04
# Epoch 192/200
# 70/70 [==============================] - 3s 42ms/step - loss: -0.6693 - val_loss: -0.5904 - lr: 5.0000e-04
# Epoch 193/200
# 70/70 [==============================] - 3s 43ms/step - loss: -0.6706 - val_loss: -0.5908 - lr: 5.0000e-04
# Epoch 194/200
# 70/70 [==============================] - 3s 41ms/step - loss: -0.6711 - val_loss: -0.5898 - lr: 5.0000e-04
# Epoch 195/200
# 70/70 [==============================] - 3s 43ms/step - loss: -0.6698 - val_loss: -0.5886 - lr: 5.0000e-04
# Epoch 196/200
# 70/70 [==============================] - 3s 42ms/step - loss: -0.6707 - val_loss: -0.5899 - lr: 5.0000e-04
# Epoch 197/200
# 70/70 [==============================] - 3s 42ms/step - loss: -0.6697 - val_loss: -0.5916 - lr: 5.0000e-04
# Epoch 198/200
# 70/70 [==============================] - 3s 42ms/step - loss: -0.6712 - val_loss: -0.5907 - lr: 5.0000e-04
# Epoch 199/200
# 70/70 [==============================] - 3s 43ms/step - loss: -0.6708 - val_loss: -0.5923 - lr: 5.0000e-04
# Epoch 200/200
# 70/70 [==============================] - 3s 42ms/step - loss: -0.6706 - val_loss: -0.5903 - lr: 5.0000e-04

# %%
# 绘制验证损失和训练损失
import matplotlib.pyplot as plt
plt.rcParams['font.sans-serif'] = [u'SimHei']
plt.rcParams['axes.unicode_minus'] = False

# 设置字体大小
plt.rcParams['font.size'] = 12

# 设置图像大小
plt.figure(figsize=(12, 6))

# 绘制训练和验证损失
plt.plot(history.history['loss'], label='训练损失')
plt.plot(history.history['val_loss'], label='验证损失')
plt.xlabel('迭代次数')
plt.ylabel('损失')
plt.title('原始模型 训练和验证损失')
plt.legend()
plt.show()

# %%
# 保存模型
model.save('D:/jupyter_note/SWX_source/Simulated_data/model_LSTM_daodianlv', save_format='tf')
# Out:
# WARNING:absl:Function `_wrapped_model` contains input name(s) Input with unsupported characters which will be renamed to input in the SavedModel.
# WARNING:absl:Found untraced functions such as gru_cell_10_layer_call_fn, gru_cell_10_layer_call_and_return_conditional_losses, gru_cell_11_layer_call_fn, gru_cell_11_layer_call_and_return_conditional_losses while saving (showing 4 of 4). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: D:/jupyter_note/SWX_source/Simulated_data/model_LSTM10\assets
# INFO:tensorflow:Assets written to: D:/jupyter_note/SWX_source/Simulated_data/model_LSTM10\assets
# WARNING:absl:<keras.layers.recurrent.GRUCell object at 0x000001B30E6A55B0> has the same name 'GRUCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.GRUCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.GRUCell object at 0x000001B30E6A59A0> has the same name 'GRUCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.GRUCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
